# %% [markdown]
# # ĐỒ ÁN THỰC HÀNH CUỐI KÌ

# %% [markdown]
# ## MÔN LẬP TRÌNH CHO KHOA HỌC DỮ LIỆU

# %% [markdown]
# **Thành viên:**
# 1. Đinh Thị Hoàng Linh - 20120130
# 2. Phạm Trần Gia Phú - 20120348
# 3. Nguyễn Anh Tuấn - 20120395
# 4. Phạm Khánh Hoàng Việt - 20120626

# %% [markdown]
# #### Mô tả dataset
# Bạn có bao giờ thắc mắc những thành phần nào có trong mỹ phẩm yêu thích của mình không?
#
# Bạn có biết rằng có hơn 12.000 hóa chất được sử dụng trong mỹ phẩm và các sản phẩm chăm sóc cá nhân?
#
# Bộ dữ liệu này chứa thông tin về các hóa chất được sử dụng trong mỹ phẩm, bao gồm tên của hóa chất, công ty sản xuất hóa chất đó, danh mục chính mà hóa chất được sử dụng và ngày báo cáo lần đầu tiên.
#
# Vậy, những gì thực sự trong túi trang điểm của bạn?
# Hãy cùng nhau xem qua một số thành phần của các loại mỹ phẩm phổ biến nhất

# %% [markdown]
# #### Cài đặt thư viện

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Phần 1. Khám phá dữ liệu (kết hợp tiền xử lý)

# %% [markdown]
# Đọc dữ liệu từ dataset vào dataframe

# %%
df = pd.read_csv("../dataset/chemicals-in-cosmetics-3.csv")
df
# Out:
#          index  CDPHId                                        ProductName  \
# 0            0       2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES
# 1            1       3                         Glover's Medicated Shampoo
# 2            2       3                         Glover's Medicated Shampoo
# 3            3       4           PRECISION GLIMMER EYE LINER-ALL SHADES �
# 4            4       5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �
# ...        ...     ...                                                ...
# 114293  114293   41445  JILLSTUART Something Pure Blue Diamond Glaze L...
# 114294  114294   41446             JILLSTUART something pure blue my lips
# 114295  114295   41449             SPRING BLOSSOM VANILLA APPLE BODY WASH
# 114296  114296   41450                 Wild Breeze Water Lilies Hand Soap
# 114297  114297   41451                         BEVEL EXFOLIATING BAR SOAP
#
#         CSFId  CSF  CompanyId                   CompanyName    BrandName  \
# 0         NaN  NaN          4                  New Avon LLC         AVON
# 1         NaN  NaN        338           J. Strickland & Co.     Glover's
# 2         NaN  NaN        338           J. Strickland & Co.     Glover's
# 3         NaN  NaN          4                  New Avon LLC         AVON
# 4         NaN  NaN          4                  New Avon LLC         AVON
# ...       ...  ...        ...                           ...          ...
# 114293    NaN  NaN       1031            KOS� America, Inc.  JILL STUART
# 114294    NaN  NaN       1031            KOS� America, Inc.  JILL STUART
# 114295    NaN  NaN       1388               Cosmopharm Ltd.     Careline
# 114296    NaN  NaN       1388               Cosmopharm Ltd.     Careline
# 114297    NaN  NaN         86  The Procter & Gamble Company        Bevel
#
#         PrimaryCategoryId                    PrimaryCategory  ...   CasNumber  \
# 0                      44    Makeup Products (non-permanent)  ...  13463-67-7
# 1                      18  Hair Care Products (non-coloring)  ...  65996-92-1
# 2                      18  Hair Care Products (non-coloring)  ...    140-67-0
# 3                      44    Makeup Products (non-permanent)  ...  13463-67-7
# 4                      44    Makeup Products (non-permanent)  ...  13463-67-7
# ...                   ...                                ...  ...         ...
# 114293                 44    Makeup Products (non-permanent)  ...  13463-67-7
# 114294                 44    Makeup Products (non-permanent)  ...  13463-67-7
# 114295                  6                      Bath Products  ...         NaN
# 114296                  6                      Bath Products  ...         NaN
# 114297                  6                      Bath Products  ...  13463-67-7
#
#        ChemicalId            ChemicalName InitialDateReported  \
# 0               6        Titanium dioxide          06/17/2009
# 1               4  Distillates (coal tar)          07/01/2009
# 2               5               Estragole          07/01/2009
# 3               7        Titanium dioxide          07/09/2009
# 4               8        Titanium dioxide          07/09/2009
# ...           ...                     ...                 ...
# 114293      67901        Titanium dioxide          04/30/2020
# 114294      67902        Titanium dioxide          04/30/2020
# 114295      67905            Cocamide DEA          04/30/2020
# 114296      67906            Cocamide DEA          04/30/2020
# 114297      67907        Titanium dioxide          05/07/2020
#
#         MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 0                   08/28/2013       02/01/2011        07/09/2009
# 1                   07/01/2009              NaN        07/01/2009
# 2                   07/01/2009              NaN        07/02/2009
# 3                   08/28/2013              NaN        07/09/2009
# 4                   08/28/2013       02/01/2011        07/09/2009
# ...                        ...              ...               ...
# 114293              04/30/2020              NaN        04/30/2020
# 114294              04/30/2020              NaN        04/30/2020
# 114295              04/30/2020              NaN        04/30/2020
# 114296              04/30/2020              NaN        04/30/2020
# 114297              05/07/2020              NaN        05/07/2020
#
#        ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 0             07/09/2009                 NaN             1
# 1             07/01/2009                 NaN             2
# 2             07/02/2009                 NaN             2
# 3             07/09/2009                 NaN             1
# 4             07/09/2009                 NaN             1
# ...                  ...                 ...           ...
# 114293        04/30/2020                 NaN             1
# 114294        04/30/2020                 NaN             1
# 114295        04/30/2020                 NaN             1
# 114296        04/30/2020                 NaN             1
# 114297        05/07/2020                 NaN             1
#
# [114298 rows x 23 columns]

# %%
df.shape
# Out:
# (114298, 23)

# %% [markdown]
# - Dữ liệu có 114298 dòng và 23 cột

# %% [markdown]
# - Mỗi dòng đại diện cho 1 thông tin của một sản phẩm

# %%
tmp = df.copy()
tmp.dropna(axis=0,subset=['CSF'])
# Out:
#          index  CDPHId                                        ProductName  \
# 6            6       7  ABSOLUTE Precision Color Powder System - All S...
# 7            7       7  ABSOLUTE Precision Color Powder System - All S...
# 8            8       7  ABSOLUTE Precision Color Powder System - All S...
# 9            9       8  ABSOLUTE Precision Color Powder System Opaque ...
# 11          11      10  ABSOLUTE Precision Color Powder System Translu...
# ...        ...     ...                                                ...
# 114286  114286   41442                             CHARLOTTE'S JEWEL LIPS
# 114287  114287   41442                             CHARLOTTE'S JEWEL LIPS
# 114288  114288   41442                             CHARLOTTE'S JEWEL LIPS
# 114289  114289   41442                             CHARLOTTE'S JEWEL LIPS
# 114290  114290   41442                             CHARLOTTE'S JEWEL LIPS
#
#           CSFId                     CSF  CompanyId  \
# 6         310.0               5858-81-1         11
# 7         311.0  D&C RED 7 CALCIUM LAKE         11
# 8         312.0              D&C RED 28         11
# 9         313.0  D&C RED 7 CALCIUM LAKE         11
# 11        314.0              D&C RED 28         11
# ...         ...                     ...        ...
# 114286  64873.0              STAR JEWEL       1154
# 114287  64874.0            BLUSHED GOLD       1154
# 114288  64874.0            BLUSHED GOLD       1154
# 114289  64874.0            BLUSHED GOLD       1154
# 114290  64874.0            BLUSHED GOLD       1154
#
#                          CompanyName          BrandName  PrimaryCategoryId  \
# 6                  OPI PRODUCTS INC.                OPI                 59
# 7                  OPI PRODUCTS INC.                OPI                 59
# 8                  OPI PRODUCTS INC.                OPI                 59
# 9                  OPI PRODUCTS INC.           ABSOLUTE                 59
# 11                 OPI PRODUCTS INC.           ABSOLUTE                 59
# ...                              ...                ...                ...
# 114286  Charlotte Tilbury Beauty Ltd  Charlotte Tilbury                 44
# 114287  Charlotte Tilbury Beauty Ltd  Charlotte Tilbury                 44
# 114288  Charlotte Tilbury Beauty Ltd  Charlotte Tilbury                 44
# 114289  Charlotte Tilbury Beauty Ltd  Charlotte Tilbury                 44
# 114290  Charlotte Tilbury Beauty Ltd  Charlotte Tilbury                 44
#
#                         PrimaryCategory  ...   CasNumber ChemicalId  \
# 6                         Nail Products  ...  13463-67-7      12178
# 7                         Nail Products  ...  13463-67-7      12178
# 8                         Nail Products  ...  13463-67-7      12178
# 9                         Nail Products  ...  13463-67-7      17903
# 11                        Nail Products  ...  13463-67-7      17911
# ...                                 ...  ...         ...        ...
# 114286  Makeup Products (non-permanent)  ...  13463-67-7      67895
# 114287  Makeup Products (non-permanent)  ...  13463-67-7      67885
# 114288  Makeup Products (non-permanent)  ...         NaN      67886
# 114289  Makeup Products (non-permanent)  ...  13463-67-7      67896
# 114290  Makeup Products (non-permanent)  ...         NaN      67897
#
#                                              ChemicalName InitialDateReported  \
# 6                                        Titanium dioxide          07/13/2009
# 7                                        Titanium dioxide          07/13/2009
# 8                                        Titanium dioxide          07/13/2009
# 9                                        Titanium dioxide          07/13/2009
# 11                                       Titanium dioxide          07/13/2009
# ...                                                   ...                 ...
# 114286                                   Titanium dioxide          04/29/2020
# 114287                                   Titanium dioxide          04/29/2020
# 114288  Silica, crystalline (airborne particles of res...          04/29/2020
# 114289                                   Titanium dioxide          04/29/2020
# 114290  Silica, crystalline (airborne particles of res...          04/29/2020
#
#         MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 6                   12/30/2010              NaN        12/04/2009
# 7                   12/30/2010              NaN        12/04/2009
# 8                   12/30/2010              NaN        12/04/2009
# 9                   12/30/2010              NaN        06/09/2010
# 11                  12/30/2010              NaN        06/09/2010
# ...                        ...              ...               ...
# 114286              04/29/2020              NaN        04/29/2020
# 114287              04/29/2020              NaN        04/29/2020
# 114288              04/29/2020              NaN        04/29/2020
# 114289              04/29/2020              NaN        04/29/2020
# 114290              04/29/2020              NaN        04/29/2020
#
#        ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 6             12/04/2009                 NaN             1
# 7             12/04/2009                 NaN             1
# 8             12/04/2009                 NaN             1
# 9             06/09/2010                 NaN             1
# 11            06/09/2010                 NaN             1
# ...                  ...                 ...           ...
# 114286        04/29/2020                 NaN             2
# 114287        04/29/2020                 NaN             2
# 114288        04/29/2020                 NaN             2
# 114289        04/29/2020                 NaN             2
# 114290        04/29/2020                 NaN             2
#
# [79958 rows x 23 columns]

# %% [markdown]
# <h4> Dữ liệu có các dòng bị lặp không

# %%
have_duplicated_rows = False
for i in df.duplicated().items():
    if(i[1] == True):
        have_duplicated_rows = True

if have_duplicated_rows == True:
    print('Dữ liệu có chứa dòng bị lặp !')
else:
    print('Dữ liệu không có chứa dòng bị lặp !')
# Out:
# Dữ liệu không có chứa dòng bị lặp !

# %% [markdown]
# **MỖI CỘT CÓ Ý NGHĨA GÌ**

# %% [markdown]
# - **CDPHId**: Số nhận dạng nội bộ của Bộ Y tế Công cộng California (CDPH) cho sản phẩm. Lưu ý rằng CDPHId có thể xuất hiện nhiều lần nếu một sản phẩm có nhiều Màu sắc/Mùi hương/Hương vị, nhiều Danh mục hoặc nhiều Tên hóa chất/số CAS được báo cáo.
# - **ProductName**: Tên của sản phẩm mà hóa chất được sử dụng.
# - **CSFId**: Số nhận dạng nội bộ CDPH cho màu sắc/mùi hương/hương vị.
# - **CSF**: Hệ số an toàn mỹ phẩm, thước đo mức độ an toàn của hóa chất được sử dụng trong mỹ phẩm.
# - **CompanyId** : Mã số nhận dạng nội bộ CDPH cho công ty.
# - **CompanyName**: Tên của công ty sản xuất sản phẩm mà hóa chất được sử dụng.
# - **BrandName**: Tên thương hiệu của sản phẩm mà hóa chất được sử dụng.
# - **PrimaryCategoryId**: Số nhận dạng nội bộ CDPH cho danh mục.
# - **PrimaryCategory**: Loại mỹ phẩm chính mà hóa chất được sử dụng.
# - **SubCategoryId**: Số nhận dạng nội bộ CDPH cho tiểu thể loại.
# - **SubCategory**: Danh mục phụ của mỹ phẩm trong đó hóa chất được sử dụng.
# - **CASId**: Số nhận dạng nội bộ CDPH cho hóa chất.
# - **CasNumber**: Số CAS của hóa chất.
# - **ChemicalId**: Số nhận dạng nội bộ CDPH cho hồ sơ hóa chất cụ thể cho sản phẩm này.
# - **ChemicalName**: Tên hóa chất.
# - **InitialDateReported**: Ngày hóa chất được báo cáo lần đầu tiên.
# - **MostRecentDateReported**: Ngày hóa chất được báo cáo gần đây nhất.
# - **DiscontinuedDate**: Ngày ngừng sản xuất sản phẩm sử dụng hóa chất.
# - **ChemicalCreatedAt**: Ngày hóa chất được tạo ra.
# - **ChemicalUpdatedAt**: Ngày hóa chất được cập nhật lần cuối.
# - **ChemicalDateRemoved**: Ngày loại bỏ hóa chất khỏi sản phẩm.
# - **ChemicalCount**: Số lượng hóa chất trong sản phẩm.

# %% [markdown]
# #### Mỗi cột hiện đang có kiểu dữ liệu gì? Có cột nào có kiểu dữ liệu chưa phù hợp để có thể xử lý tiếp không?

# %%
df.dtypes
# Out:
# index                       int64
# CDPHId                      int64
# ProductName                object
# CSFId                     float64
# CSF                        object
# CompanyId                   int64
# CompanyName                object
# BrandName                  object
# PrimaryCategoryId           int64
# PrimaryCategory            object
# SubCategoryId               int64
# SubCategory                object
# CasId                       int64
# CasNumber                  object
# ChemicalId                  int64
# ChemicalName               object
# InitialDateReported        object
# MostRecentDateReported     object
# DiscontinuedDate           object
# ChemicalCreatedAt          object
# ChemicalUpdatedAt          object
# ChemicalDateRemoved        object
# ChemicalCount               int64
# dtype: object

# %% [markdown]
# <b>Nhận xét</b>
# <br> Hầu hết các cột đều có kiểu dữ liệu phù hợp. Tuy nhiên, các cột InitialDateReported, MostRecentDateReported, DiscontinuedDate, ChemicalCreatedAt, ChemicalUpdatedAt, ChemicalDateRemoved có dạng tháng/ngày/năm nhưng có kiểu object chưa phù hợp. Nên ta cần phải chuyển kiểu dữ liệu các cột này sang kiểu datetime.

# %% [markdown]
# #### Chuyển các cột  **'InitialDateReported'** , **'MostRecentDateReported'** , **'DiscontinuedDate'** , **'ChemicalCreatedAt'** , **'ChemicalUpdatedAt'** , **'ChemicalDateRemoved'** về dạng datetime

# %%
df[['InitialDateReported',
    'MostRecentDateReported',   
    'DiscontinuedDate', 
    'ChemicalCreatedAt',    
    'ChemicalUpdatedAt',    
    'ChemicalDateRemoved']] = pd.to_datetime(df[['InitialDateReported',
                                                'MostRecentDateReported',   
                                                'DiscontinuedDate', 
                                                'ChemicalCreatedAt',    
                                                'ChemicalUpdatedAt',    
                                                'ChemicalDateRemoved']].stack()).unstack()

# %%
# Kiểm tra lại kiể dữ liệu của các cột sau khi chuyển đổi
df[['InitialDateReported',
    'MostRecentDateReported',   
    'DiscontinuedDate', 
    'ChemicalCreatedAt',    
    'ChemicalUpdatedAt',    
    'ChemicalDateRemoved']].dtypes
# Out:
# InitialDateReported       datetime64[ns]
# MostRecentDateReported    datetime64[ns]
# DiscontinuedDate          datetime64[ns]
# ChemicalCreatedAt         datetime64[ns]
# ChemicalUpdatedAt         datetime64[ns]
# ChemicalDateRemoved       datetime64[ns]
# dtype: object

# %% [markdown]
# #### Các cột kiểu dữ liệu Numeric

# %%
numberic_cols = df.select_dtypes(include=np.number).columns
numberic_cols
# Out:
# Index(['index', 'CDPHId', 'CSFId', 'CompanyId', 'PrimaryCategoryId',
#        'SubCategoryId', 'CasId', 'ChemicalId', 'ChemicalCount'],
#       dtype='object')

# %% [markdown]
# <h4> Kiểm tra phân bố dữ liệu của cột có kiểu số

# %%
index = ["missing_values","missing_ratio", "min", "max"]
def missingValues(s):
    temp = s.isna()
    return len(temp[temp==True])
def missingRatio(s):
    temp = s.isna()
    return round((len(temp[temp==True])/len(s))*100,3)

maxValue = []
for i in numberic_cols:
    maxValue.append(df[i].max())

minValue = []
for i in numberic_cols:
    minValue.append(df[i].min())
    
missing_ratio = []
for i in numberic_cols:
    missing_ratio.append(missingRatio(df[i]))

missing_values = []
for i in numberic_cols:
    missing_values.append(missingValues(df[i]))
    
data = [missing_values,missing_ratio,minValue,maxValue]
numberic_col_profiles = pd.DataFrame(data,index,numberic_cols)

# %%
numberic_col_profiles
# Out:
#                    index   CDPHId      CSFId  CompanyId  PrimaryCategoryId  \
# missing_values       0.0      0.0  33916.000        0.0                0.0
# missing_ratio        0.0      0.0     29.673        0.0                0.0
# min                  0.0      2.0      1.000        4.0                1.0
# max             114297.0  41451.0  64883.000     1391.0              111.0
#
#                 SubCategoryId   CasId  ChemicalId  ChemicalCount
# missing_values            0.0     0.0         0.0            0.0
# missing_ratio             0.0     0.0         0.0            0.0
# min                       3.0     2.0         0.0            0.0
# max                     172.0  1242.0     67907.0            9.0

# %% [markdown]
# #### Kiểm tra phân bố dữ liệu của các cột có kiểu phân loại

# %%
# tính số giá trị thiếu của cột s
def missing_num(s):
    return s.isnull().sum()

# Tính số tỉ lệ phần trăm giá trị thiếu của cột s 
def missing_ratio(s):
    return s.isnull().sum()/len(s)*100

# Tính số giá trị khác nhau (không tính giá trị thiếu) của cột s
def n_diff_vals(s):
    return s.dropna().unique().size

# Các giá trị khác nhau (không xét giá trị thiếu) của cột s
def diff_vals(s):
    return s.dropna().unique()

# Tên các cột thuộc kiểu dữ liệu dạng phân loại (category)
cate_index = ['ProductName', 'CSF', 'CompanyName', 'BrandName', 'PrimaryCategory',\
            'SubCategory', 'CasNumber', 'ChemicalName']

cate_columns = ['missing_num','missing_ratio', 'n_diff_vals', 'diff_vals']

cate_data = np.array([[
                missing_num(df[i]),
                missing_ratio(df[i]),
                n_diff_vals(df[i]),
                diff_vals(df[i]),
            ] for i in cate_index], dtype = object)

cate_col_profiles_df = pd.DataFrame(data=cate_data, columns=cate_columns, index=cate_index)

# %%
cate_col_profiles_df
# Out:
#                 missing_num missing_ratio n_diff_vals  \
# ProductName               0           0.0       33638
# CSF                   34340      30.04427       34258
# CompanyName               0           0.0         606
# BrandName               216       0.18898        2711
# PrimaryCategory           0           0.0          13
# SubCategory               0           0.0          89
# CasNumber              6396      5.595898         125
# ChemicalName              0           0.0         123
#
#                                                          diff_vals
# ProductName      [ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHA...
# CSF              [5858-81-1, D&C RED 7 CALCIUM LAKE, D&C RED 28...
# CompanyName      [New Avon LLC, J. Strickland & Co., OPI PRODUC...
# BrandName        [AVON, Glover's, OPI, ABSOLUTE, ABSOLUTE FX, G...
# PrimaryCategory  [Makeup Products (non-permanent), Hair Care Pr...
# SubCategory      [Lip Color - Lipsticks, Liners, and Pencils, H...
# CasNumber        [13463-67-7, 65996-92-1, 140-67-0, 68603-42-9,...
# ChemicalName     [Titanium dioxide, Distillates (coal tar), Est...

# %% [markdown]
# <b>Nhận xét</b>:
# <br>Số lượng giá trị thiếu (missing_num)
# - Có 34340 dòng bị mất giá trị ở cột 'CSF'
# - Có 216 dòng bị mất giá trị ở cột 'BrandName'
# - Có 6396 dòng bị mất giá trị ở cột 'CasNumber'
#
# <br>Tỉ lệ phần trăm giá trị thiếu (missing_ratio)
# - Có 30% dòng bị mất giá trị ở cột 'CSF'
# - Có 0.2% dòng bị mất giá trị ở cột 'BrandName'
# - Có 5.6% dòng bị mất giá trị ở cột 'CasNumber'

# %% [markdown]
# <h2> Tiền xử lý

# %% [markdown]
# <H5> Tác vụ 1: Đổi tên giá trị 'Cocamide diethanolamine' thành 'Cocamide DEA' tại cột 'ChemicalName' vì hai tên gọi đều của cùng một chất.

# %%
df.loc[df['ChemicalName'] == 'Cocamide diethanolamine', 'ChemicalName'] = 'Cocamide DEA'

# %% [markdown]
# ## Phần 2. Trả lời câu hỏi

# %% [markdown]
# <h3> Câu 1: Top 10 các loại hoá chất được sử dụng nhiều nhất

# %% [markdown]
# Hẳn là ai cũng muốn biết trong sản phẩm mình sử dụng chứa thành phần chính là gì đúng không? Hãy điểm qua top 10 loại hoá chất được sử dụng nhiều nhất trong mỹ phẩm để xem thử loại hoá chất nào được các nhãn hàng ưa chuộn nhất nhé :D

# %%
df['ChemicalName'].value_counts()
# Out:
# Titanium dioxide                                                                                       93252
# Silica, crystalline (airborne particles of respirable size)                                             2742
# Retinol/retinyl esters, when in daily dosages in excess of 10,000 IU, or 3,000 retinol equivalents.     2154
# Mica                                                                                                    1911
# Butylated hydroxyanisole                                                                                1888
#                                                                                                        ...
# Acetylsalicylic acid                                                                                       1
# 2-Propyleneacrolein                                                                                        1
# Spironolactone                                                                                             1
# Extract of coffee bean                                                                                     1
# Cocamide                                                                                                   1
# Name: ChemicalName, Length: 122, dtype: int64

# %%
top10_chems = df['ChemicalName'].value_counts().to_frame('counts').head(10)
top10_chems
# Out:
#                                                     counts
# Titanium dioxide                                     93252
# Silica, crystalline (airborne particles of resp...    2742
# Retinol/retinyl esters, when in daily dosages i...    2154
# Mica                                                  1911
# Butylated hydroxyanisole                              1888
# Carbon black                                          1753
# Cocamide DEA                                          1631
# Talc                                                  1534
# Retinyl palmitate                                     1181
# Vitamin A palmitate                                    971

# %%
top10_chems.plot.barh(ylabel='Loại hoá chất',xlabel='Số lượng sử dụng')
# Out:
# <AxesSubplot:xlabel='Số lượng sử dụng', ylabel='Loại hoá chất'>

# %% [markdown]
# - Có thể thấy Titanium dioxide được sử dụng rất nhiều, có thể là đa phần trong các loại mỹ phẩm hiện nay.
# - Titanium dioxide hay còn gọi là Titania, là một hợp chất tự nhiên. Khi sử dụng trong các sản phẩm mỹ phẩm tại Liên minh Châu âu (EU), Titanium dioxide thô sau khi khai thác sẽ được các chuyên gia xử lý và tinh chế cho phù hợp với mục đích sản xuất.
# - Là một dạng oxit tự nhiên có trong titan với công thức hóa học là TiO2, Titanium dioxide có nhiều tính chất vật lý bền vững cả về mức độ chịu nhiệt và hóa học, bên cạnh đó chất này còn có độ che phủ lớn và rất dẻo dai.
# - Titanium dioxide có dạng bột mịn màu trắng, có độ tương phản cao và có khả năng tạo ra sắc tố trắng sáng nên thường dùng làm nền cho các loại mỹ phẩm.
# - Nó có tính hấp thụ, phản xạ hoặc tán xạ ánh sáng (bao gồm cả tia UV từ mặt trời). Vì nó bảo vệ da khỏi cả bức xạ UVA và UVB, Titanium dioxide đã được sử dụng trong kem chống nắng trong nhiều thập kỷ. Và bởi vì nó ít gây kích ứng hơn các hóa chất hấp thụ tia cực tím như oxybenzone, nên nó thường là thành phần hoạt chất trong kem chống nắng cho trẻ sơ sinh và những người có làn da nhạy cảm.

# %% [markdown]
# <h3> Câu 2: Top 10 những hóa chất đã được loại bỏ nhiều nhất

# %% [markdown]
# Những hóa chất bị loại bỏ có thể do một vài nguyên nhân như có nhiều báo cáo không tốt cho sức khỏe con người hoặc các thành phần đó không tốt cho môi trường, vv.. Những hóa chất như vậy cũng đáng để ta quan tâm và tránh sử dụng.

# %% [markdown]
# Loại bỏ các dòng có giá trị null tại cột 'ChemicalDateRemoved'

# %%
RemovedChemical_df = df.copy().dropna(subset=['ChemicalDateRemoved'])

# %% [markdown]
# Giữ lại 1 cột quan tâm là 'ChemicalName'

# %%
RemovedChemical_df = RemovedChemical_df[['ChemicalName']]

# %% [markdown]
# Đếm số lượng dòng theo tên hóa chất, sắp xếp theo chiều giảm dần, thêm vào cột 'counts' và lấy ra 10 giá trị lớn nhất.

# %%
top_10_removed = RemovedChemical_df.value_counts(ascending=False).head(10).to_frame('Counts')
display(top_10_removed)
# Out:
#                                                     Counts
# ChemicalName
# Titanium dioxide                                      1626
# Cocamide DEA                                           357
# Silica, crystalline (airborne particles of resp...     135
# Retinol/retinyl esters, when in daily dosages i...     125
# Carbon black (airborne, unbound particles of re...      79
# Butylated hydroxyanisole                                71
# Estragole                                               57
# Toluene                                                 46
# Acetaldehyde                                            35
# Lauramide DEA                                           33

# %%
top_10_removed.plot.barh(ylabel='Tên hoá chất',xlabel='Số lượng sản phẩm loại bỏ')
# Out:
# <AxesSubplot:xlabel='Số lượng sản phẩm loại bỏ', ylabel='Tên hoá chất'>

# %% [markdown]
# <b>Nhật xét:</b>
# <br>
# - <b>Titanium dioxit</b> là hóa chất có nhiều sản phẩm loại bỏ nhất.
# - Tuy <b>Cocamide DEA</b> có số loại bỏ đứng thứ hai nhưng lại có số lượng sản phẩm sử dụng nhỏ hơn rất nhiều so với Titanium dioxit (biểu đồ câu hỏi số 1). Điều đó dẫn đến câu hỏi tại sao Cocamide DEA lại bị loại bỏ nhiều như vậy?
#
# <br>
# Cocamide diethanolamine hay Cocamide DEA được sử dụng trong các sản phẩm sữa rửa mặt, dầu gội đầu hay nước rửa tay như một chất tạo bọt. Cocamide DEA được tuyên bố là an toàn ở nồng độ dưới 10%. Tuy nhiên, việc sử dụng thành phần này đã giảm trong nhưng năm qua. Điều này do việc sử dụng nhiều và kéo dài Cocamide DEA có liên quan đến ung thư. Ngay ở số lượng nhỏ, nó có thể gây một số tác dụng phụ như ngứa. Hơn nữa Cocamide DEA có thể tác dụng với các chất khác tạo ra các chất có hại được gọi là nitrosamine. Cocamide DEA được xếp ở mức 7 trên thang 10 của EWG (trong đó 1 là thấp nhất, 10 là cao nhất về mức độ nguy hiểm).
#
# <h10>(EWG - Environmental Working Group, là một tổ chức phi lợi nhuận của Mỹ chuyên nghiên cứu và vận động chính sách trong các lĩnh vực trợ cấp nông nghiệp, hóa chất độc hại, chất gây ô nhiễm nước uống và trách nhiệm giải trình của công ty.)</h10>
#
# Vì vậy, mỗi lần mua sản phẩm có nhiều bọt như dầu gội đầu, nước rửa mặt, nước rửa, ... ta nên tránh những sản phẩm có thành phần Cocamide DEA.

# %% [markdown]
# <h3> Câu 3: Các hãng sản xuất mỹ phẩm có sản phẩm chứa nhiều hóa chất?

# %% [markdown]
# Khám phá các hãng mỹ phẩm sử dụng nhiều loại hoá chất cho sản phẩm của mình nhé :v Để biết xem hãng nào có nhiều hoá chất và đưa ra lựa chọn phù hợp

# %%
chemical_count = df['ChemicalCount'].value_counts().to_frame('counts').head(10)
chemical_count
# Out:
#    counts
# 1   87132
# 2   21133
# 3    3515
# 4    1437
# 0     857
# 5     105
# 8      41
# 7      36
# 6      33
# 9       9

# %% [markdown]
# Có thể thấy đại đa số các sản phẩm mỹ phẩm có từ 4 chất hóa học trở xuống, với phần lớn trong số đó có thành phần chứa 1 chất hóa học.
#
# Tiếp theo chúng ta sẽ xem thử thông tin của các sản phẩm có từ 5 chất hóa học trở lên, do chúng ta muốn biết những sản phẩm nào có chứa nhiều chất hóa học, và những công ty nào có thói quen sử dụng nhiều chất hóa học trong sản phẩm của mình (để né :v)

# %%
# Products with 9 chemicals in its ingredient
df[df['ChemicalCount'] == 9]
# Out:
#        index  CDPHId           ProductName  CSFId  CSF  CompanyId  \
# 60819  60819   22212  Moisturizing Shampoo    NaN  NaN        165
# 60820  60820   22212  Moisturizing Shampoo    NaN  NaN        165
# 60821  60821   22212  Moisturizing Shampoo    NaN  NaN        165
# 60822  60822   22212  Moisturizing Shampoo    NaN  NaN        165
# 60823  60823   22212  Moisturizing Shampoo    NaN  NaN        165
# 60824  60824   22212  Moisturizing Shampoo    NaN  NaN        165
# 60825  60825   22212  Moisturizing Shampoo    NaN  NaN        165
# 60826  60826   22212  Moisturizing Shampoo    NaN  NaN        165
# 60827  60827   22212  Moisturizing Shampoo    NaN  NaN        165
#
#              CompanyName          BrandName  PrimaryCategoryId  \
# 60819  Regis Corporation  Regis Design Line                 18
# 60820  Regis Corporation  Regis Design Line                 18
# 60821  Regis Corporation  Regis Design Line                 18
# 60822  Regis Corporation  Regis Design Line                 18
# 60823  Regis Corporation  Regis Design Line                 18
# 60824  Regis Corporation  Regis Design Line                 18
# 60825  Regis Corporation  Regis Design Line                 18
# 60826  Regis Corporation  Regis Design Line                 18
# 60827  Regis Corporation  Regis Design Line                 18
#
#                          PrimaryCategory  ...  CasNumber ChemicalId  \
# 60819  Hair Care Products (non-coloring)  ...   123-91-1      33796
# 60820  Hair Care Products (non-coloring)  ...    79-06-1      33797
# 60821  Hair Care Products (non-coloring)  ...        NaN      33798
# 60822  Hair Care Products (non-coloring)  ...    79-43-6      33799
# 60823  Hair Care Products (non-coloring)  ...    75-21-8      33800
# 60824  Hair Care Products (non-coloring)  ...    50-00-0      33801
# 60825  Hair Care Products (non-coloring)  ...  7439-92-1      33802
# 60826  Hair Care Products (non-coloring)  ...        NaN      33803
# 60827  Hair Care Products (non-coloring)  ...   107-21-1      33804
#
#                                 ChemicalName InitialDateReported  \
# 60819                            1,4-Dioxane          2014-02-04
# 60820                             Acrylamide          2014-02-04
# 60821  Arsenic (inorganic arsenic compounds)          2014-02-04
# 60822                    Dichloroacetic acid          2014-02-04
# 60823                         Ethylene oxide          2014-02-04
# 60824                     Formaldehyde (gas)          2014-02-04
# 60825                                   Lead          2014-02-04
# 60826          Cocamide diethanolamine (DEA)          2014-02-04
# 60827                        Ethylene glycol          2014-02-04
#
#        MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 60819              2014-02-04              NaT        2014-02-04
# 60820              2014-02-04              NaT        2014-02-04
# 60821              2014-02-04              NaT        2014-02-04
# 60822              2014-02-04              NaT        2014-02-04
# 60823              2014-02-04              NaT        2014-02-04
# 60824              2014-02-04              NaT        2014-02-04
# 60825              2014-02-04              NaT        2014-02-04
# 60826              2014-02-04              NaT        2014-02-04
# 60827              2014-02-04              NaT        2014-02-04
#
#       ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 60819        2014-02-04                 NaT             9
# 60820        2014-02-04                 NaT             9
# 60821        2014-02-04                 NaT             9
# 60822        2014-02-04                 NaT             9
# 60823        2014-02-04                 NaT             9
# 60824        2014-02-04                 NaT             9
# 60825        2014-02-04                 NaT             9
# 60826        2014-02-04                 NaT             9
# 60827        2014-02-04                 NaT             9
#
# [9 rows x 23 columns]

# %%
# Products with 8 chemicals in its ingredient
df[df['ChemicalCount'] == 8]
# Out:
#        index  CDPHId                  ProductName  CSFId  CSF  CompanyId  \
# 15654  15654    3685          Hydrate Conditioner    NaN  NaN        165
# 15655  15655    3685          Hydrate Conditioner    NaN  NaN        165
# 15656  15656    3685          Hydrate Conditioner    NaN  NaN        165
# 15657  15657    3685          Hydrate Conditioner    NaN  NaN        165
# 15658  15658    3685          Hydrate Conditioner    NaN  NaN        165
# 15659  15659    3685          Hydrate Conditioner    NaN  NaN        165
# 15660  15660    3685          Hydrate Conditioner    NaN  NaN        165
# 15661  15661    3685          Hydrate Conditioner    NaN  NaN        165
# 15662  15662    3685          Hydrate Conditioner    NaN  NaN        165
# 15663  15663    3685          Hydrate Conditioner    NaN  NaN        165
# 15664  15664    3685          Hydrate Conditioner    NaN  NaN        165
# 15665  15665    3685          Hydrate Conditioner    NaN  NaN        165
# 15666  15666    3685          Hydrate Conditioner    NaN  NaN        165
# 15667  15667    3685          Hydrate Conditioner    NaN  NaN        165
# 15668  15668    3685          Hydrate Conditioner    NaN  NaN        165
# 15669  15669    3685          Hydrate Conditioner    NaN  NaN        165
# 15726  15726    3702   Interrupt Texturizing Clay    NaN  NaN        165
# 15727  15727    3702   Interrupt Texturizing Clay    NaN  NaN        165
# 15728  15728    3702   Interrupt Texturizing Clay    NaN  NaN        165
# 15729  15729    3702   Interrupt Texturizing Clay    NaN  NaN        165
# 15730  15730    3702   Interrupt Texturizing Clay    NaN  NaN        165
# 15731  15731    3702   Interrupt Texturizing Clay    NaN  NaN        165
# 17622  Regis Corporation         Mastercuts                 18
# 17623  Regis Corporation         Mastercuts                 18
# 17624  Regis Corporation         Mastercuts                 18
# 17625  Regis Corporation         Mastercuts                 18
# 17626  Regis Corporation         Mastercuts                 18
#
#                          PrimaryCategory  ...   CasNumber ChemicalId  \
# 15654  Hair Care Products (non-coloring)  ...    123-91-1       6507
# 15655  Hair Care Products (non-coloring)  ...     75-07-0       6508
# 15656  Hair Care Products (non-coloring)  ...     71-43-2       6509
# 15657  Hair Care Products (non-coloring)  ...    100-44-7       6510
# 15658  Hair Care Products (non-coloring)  ...     75-21-8       6511
# 15659  Hair Care Products (non-coloring)  ...     75-09-2       6512
# 15660  Hair Care Products (non-coloring)  ...     62-75-9       6513
# 15661  Hair Care Products (non-coloring)  ...     75-56-9       6514
# 15662  Hair Care Products (non-coloring)  ...    123-91-1       6988
# 15663  Hair Care Products (non-coloring)  ...     75-07-0       6989
# 15664  Hair Care Products (non-coloring)  ...     71-43-2       6990
# 15665  Hair Care Products (non-coloring)  ...    100-44-7       6991
# 15666  Hair Care Products (non-coloring)  ...     75-21-8       6992
# 15667  Hair Care Products (non-coloring)  ...     75-09-2       6993
# 15668  Hair Care Products (non-coloring)  ...     62-75-9       6994
# 15669  Hair Care Products (non-coloring)  ...     75-56-9       6995
# 15726  Hair Care Products (non-coloring)  ...           0          0
# 15727  Hair Care Products (non-coloring)  ...    123-91-1       6550
# 15728  Hair Care Products (non-coloring)  ...     75-07-0       6551
# 15729  Hair Care Products (non-coloring)  ...     75-21-8       6552
# 15730  Hair Care Products (non-coloring)  ...     50-00-0       6553
# 15731  Hair Care Products (non-coloring)  ...     74-87-3       6554
# 15732  Hair Care Products (non-coloring)  ...         NaN       6556
# 15733  Hair Care Products (non-coloring)  ...  13463-67-7      33839
# 15734  Hair Care Products (non-coloring)  ...         NaN      33840
# 15745  Hair Care Products (non-coloring)  ...    123-91-1       6569
# 15746  Hair Care Products (non-coloring)  ...     75-07-0       6570
# 15747  Hair Care Products (non-coloring)  ...     71-43-2       6571
# 15748  Hair Care Products (non-coloring)  ...    100-44-7       6572
# 15749  Hair Care Products (non-coloring)  ...     75-21-8       6573
# 15750  Hair Care Products (non-coloring)  ...     50-00-0       6574
# 15751  Hair Care Products (non-coloring)  ...     62-75-9       6575
# 15752  Hair Care Products (non-coloring)  ...     75-56-9       6576
# 17619  Hair Care Products (non-coloring)  ...    123-91-1       7210
# 17620  Hair Care Products (non-coloring)  ...     75-07-0       7211
# 17621  Hair Care Products (non-coloring)  ...     71-43-2       7212
# 17622  Hair Care Products (non-coloring)  ...    100-44-7       7213
# 17623  Hair Care Products (non-coloring)  ...     75-21-8       7214
# 17624  Hair Care Products (non-coloring)  ...     50-00-0       7215
# 17625  Hair Care Products (non-coloring)  ...     62-75-9       7216
# 17626  Hair Care Products (non-coloring)  ...     75-56-9       7217
#
#                                             ChemicalName InitialDateReported  \
# 15654                                        1,4-Dioxane          2009-10-12
# 15655                                       Acetaldehyde          2009-10-12
# 15732              2014-02-04              NaT        2009-10-12
# 15733              2014-02-04              NaT        2014-02-04
# 15734              2014-02-04              NaT        2014-02-04
# 15745              2014-02-05              NaT        2009-10-12
# 15746              2014-02-05              NaT        2009-10-12
# 15747              2014-02-05              NaT        2009-10-12
# 15748              2014-02-05              NaT        2009-10-12
# 15749              2014-02-05              NaT        2009-10-12
# 15750              2014-02-05              NaT        2009-10-12
# 15751              2014-02-05              NaT        2009-10-12
# 15752              2014-02-05              NaT        2009-10-12
# 17619              2014-02-04       2013-04-01        2009-10-13
# 17620              2014-02-04       2013-04-01        2009-10-13
# 17621              2014-02-04       2013-04-01        2009-10-13
# 17622              2014-02-04       2013-04-01        2009-10-13
# 17623              2014-02-04       2013-04-01        2009-10-13
# 17624              2014-02-04       2013-04-01        2009-10-13
# 17625              2014-02-04       2013-04-01        2009-10-13
# 17626              2014-02-04       2013-04-01        2009-10-13
#
#       ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 15654        2014-02-06          2009-10-13             8
# 15655        2014-02-06          2009-10-13             8
# 15656        2014-02-06          2009-10-13             8
# 15657        2014-02-06          2009-10-13             8
# 15658        2014-02-06          2009-10-13             8
# 15659        2014-02-06          2009-10-12             8
# 15660        2014-02-06          2009-10-13             8
# 15661        2014-02-06          2009-10-13             8
# 15662        2014-02-06                 NaT             8
# 15663        2014-02-06                 NaT             8
# 15664        2014-02-06                 NaT             8
# 15665        2014-02-06                 NaT             8
# 15666        2014-02-06                 NaT             8
# 15667        2014-02-06                 NaT             8
# 15668        2014-02-06                 NaT             8
# 15669        2014-02-06                 NaT             8
# 15726        2014-02-04          2014-02-04             8
# 15727        2014-02-04                 NaT             8
# 15728        2014-02-04                 NaT             8
# 15729        2014-02-04                 NaT             8
# 15730        2014-02-04                 NaT             8
# 15731        2014-02-04                 NaT             8
# 15732        2014-02-04                 NaT             8
# 15733        2014-02-04                 NaT             8
# 15734        2014-02-04                 NaT             8
# 15745        2014-02-05                 NaT             8
# 15746        2014-02-05                 NaT             8
# 15747        2014-02-05                 NaT             8
# 15748        2014-02-05                 NaT             8
# 15749        2014-02-05                 NaT             8
# 15750        2014-02-05                 NaT             8
# 15751        2014-02-05                 NaT             8
# 15752        2014-02-05                 NaT             8
# 17619        2014-02-06                 NaT             8
# 17620        2014-02-06                 NaT             8
# 17621        2014-02-06                 NaT             8
# 17622        2014-02-06                 NaT             8
# 17623        2014-02-06                 NaT             8
# 17624        2014-02-06                 NaT             8
# 17625        2014-02-06                 NaT             8
# 17626        2014-02-06                 NaT             8
#
# [41 rows x 23 columns]

# %%
# Products with 7 chemicals in its ingredient
df[df['ChemicalCount'] == 7]
# Out:
#        index  CDPHId                     ProductName  CSFId  CSF  CompanyId  \
# 15612  15612    3671                 Hydrate Shampoo    NaN  NaN        165
# 15613  15613    3671                 Hydrate Shampoo    NaN  NaN        165
# 15614  15614    3671                 Hydrate Shampoo    NaN  NaN        165
# 15615  15615    3671                 Hydrate Shampoo    NaN  NaN        165
# 15616  15616    3671                 Hydrate Shampoo    NaN  NaN        165
# 15773  Regis Corporation  Regis Design Line                 18
# 15774  Regis Corporation  Regis Design Line                 18
# 15775  Regis Corporation  Regis Design Line                 18
# 15776  Regis Corporation  Regis Design Line                 18
# 17518  Regis Corporation        Costcutters                 18
# 17519  Regis Corporation        Costcutters                 18
# 17520  Regis Corporation        Costcutters                 18
# 17521  Regis Corporation        Costcutters                 18
# 17522  Regis Corporation        Costcutters                 18
# 17523  Regis Corporation        Costcutters                 18
# 17524  Regis Corporation        Costcutters                 18
# 17561  Regis Corporation         Mastercuts                 18
# 17562  Regis Corporation         Mastercuts                 18
# 17563  Regis Corporation         Mastercuts                 18
# 17564  Regis Corporation         Mastercuts                 18
# 17565  Regis Corporation         Mastercuts                 18
# 17566  Regis Corporation         Mastercuts                 18
# 17567  Regis Corporation         Mastercuts                 18
#
#                          PrimaryCategory  ...  CasNumber ChemicalId  \
# 15612  Hair Care Products (non-coloring)  ...   123-91-1       6479
# 15613  Hair Care Products (non-coloring)  ...        NaN       6480
# 15614  Hair Care Products (non-coloring)  ...    79-43-6       6481
# 15615  Hair Care Products (non-coloring)  ...    75-21-8       6482
# 15616  Hair Care Products (non-coloring)  ...    50-00-0       6483
# 15617  Hair Care Products (non-coloring)  ...  7439-92-1       6484
# 15618  Hair Care Products (non-coloring)  ...    75-09-2       6485
# 15619  Hair Care Products (non-coloring)  ...   123-91-1       6591
# 15620  Hair Care Products (non-coloring)  ...        NaN       6592
# 15621  Hair Care Products (non-coloring)  ...    79-43-6       6593
# 15622  Hair Care Products (non-coloring)  ...    75-09-2       6599
# 15623  Hair Care Products (non-coloring)  ...    75-21-8       6600
# 15624  Hair Care Products (non-coloring)  ...    50-00-0       6601
# 15625  Hair Care Products (non-coloring)  ...  7439-92-1       6602
# 15769  Hair Care Products (non-coloring)  ...          0          0
# 15770  Hair Care Products (non-coloring)  ...   123-91-1       6582
# 15771  Hair Care Products (non-coloring)  ...    75-21-8       6583
# 15772  Hair Care Products (non-coloring)  ...    50-00-0       6584
# 15773  Hair Care Products (non-coloring)  ...    74-87-3       6585
# 15774  Hair Care Products (non-coloring)  ...        NaN      33832
# 15775  Hair Care Products (non-coloring)  ...    75-07-0      33833
# 15776  Hair Care Products (non-coloring)  ...    79-81-2      33834
# 17518  Hair Care Products (non-coloring)  ...   123-91-1       7167
# 17519  Hair Care Products (non-coloring)  ...    75-07-0       7168
# 17520  Hair Care Products (non-coloring)  ...    75-21-8       7169
# 17521  Hair Care Products (non-coloring)  ...    50-00-0       7170
# 17522  Hair Care Products (non-coloring)  ...    74-87-3       7171
# 17523  Hair Care Products (non-coloring)  ...    75-09-2       7172
# 17524  Hair Care Products (non-coloring)  ...        NaN       7173
# 17561  Hair Care Products (non-coloring)  ...   123-91-1       7185
# 17562  Hair Care Products (non-coloring)  ...    75-07-0       7186
# 17563  Hair Care Products (non-coloring)  ...    75-21-8       7187
# 17564  Hair Care Products (non-coloring)  ...    50-00-0       7188
# 17565  Hair Care Products (non-coloring)  ...    74-87-3       7189
# 15775              2014-02-04              NaT        2014-02-04
# 15776              2014-02-04              NaT        2014-02-04
# 17518              2014-02-04       2013-04-01        2009-10-13
# 17519              2014-02-04       2013-04-01        2009-10-13
# 17520              2014-02-04       2013-04-01        2009-10-13
# 17521              2014-02-04       2013-04-01        2009-10-13
# 17522              2014-02-04       2013-04-01        2009-10-13
# 17523              2014-02-04       2013-04-01        2009-10-13
# 17524              2014-02-04       2013-04-01        2009-10-13
# 17561              2014-02-04       2013-04-01        2009-10-13
# 17562              2014-02-04       2013-04-01        2009-10-13
# 17563              2014-02-04       2013-04-01        2009-10-13
# 17564              2014-02-04       2013-04-01        2009-10-13
# 17565              2014-02-04       2013-04-01        2009-10-13
# 17566              2014-02-04       2013-04-01        2009-10-13
# 17567              2014-02-04       2013-04-01        2009-10-13
#
#       ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 15612        2014-02-06          2009-10-12             7
# 15613        2014-02-06          2009-10-12             7
# 15614        2014-02-06          2009-10-12             7
# 15615        2014-02-06          2009-10-12             7
# 15616        2014-02-06          2009-10-12             7
# 15617        2014-02-06          2009-10-12             7
# 15618        2014-02-06          2009-10-12             7
# 15619        2014-02-06                 NaT             7
# 15620        2014-02-06                 NaT             7
# 15621        2014-02-06                 NaT             7
# 15622        2014-02-06                 NaT             7
# 15623        2014-02-06                 NaT             7
# 15624        2014-02-06                 NaT             7
# 15625        2014-02-06                 NaT             7
# 15769        2014-02-04          2014-02-04             7
# 15770        2014-02-04                 NaT             7
# 15771        2014-02-04                 NaT             7
# 15772        2014-02-04                 NaT             7
# 15773        2014-02-04                 NaT             7
# 15774        2014-02-04                 NaT             7
# 15775        2014-02-04                 NaT             7
# 15776        2014-02-04                 NaT             7
# 17518        2014-02-06                 NaT             7
# 17519        2014-02-06                 NaT             7
# 17520        2014-02-06                 NaT             7
# 17521        2014-02-06                 NaT             7
# 17522        2014-02-06                 NaT             7
# 17523        2014-02-06                 NaT             7
# 17524        2014-02-06                 NaT             7
# 17561        2014-02-06                 NaT             7
# 17562        2014-02-06                 NaT             7
# 17563        2014-02-06                 NaT             7
# 17564        2014-02-06                 NaT             7
# 17565        2014-02-06                 NaT             7
# 17566        2014-02-06                 NaT             7
# 17567        2014-02-06                 NaT             7
#
# [36 rows x 23 columns]

# %%
# Products with 6 chemicals in its ingredient
df[df['ChemicalCount'] == 6]
# Out:
#          index  CDPHId                                        ProductName  \
# 111869  111869   40753                              Sunkissed Highlighter
# 111870  111870   40753                              Sunkissed Highlighter
# 111871  111871   40753                              Sunkissed Highlighter
# 111872  111872   40753                              Sunkissed Highlighter
# 111873  111873   40753                              Sunkissed Highlighter
# 111874  111874   40753                              Sunkissed Highlighter
# 111875  111875   40753                              Sunkissed Highlighter
# 111876  111876   40753                              Sunkissed Highlighter
# 111877  111877   40753                              Sunkissed Highlighter
# 111878  111878   40753                              Sunkissed Highlighter
# 111879  111879   40753                              Sunkissed Highlighter
# 111880  111880   40753                              Sunkissed Highlighter
# 111881  111881   40753                              Sunkissed Highlighter
ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 111869        2019-12-30                 NaT             6
# 111870        2019-12-30                 NaT             6
# 111871        2019-12-31                 NaT             6
# 111872        2020-01-02                 NaT             6
# 111873        2020-01-02                 NaT             6
# 111874        2020-01-02                 NaT             6
# 111875        2019-12-30                 NaT             6
# 111876        2019-12-30                 NaT             6
# 111877        2019-12-31                 NaT             6
# 111878        2020-01-02                 NaT             6
# 111879        2020-01-02                 NaT             6
# 111880        2020-01-02                 NaT             6
# 111881        2019-12-30                 NaT             6
# 111882        2019-12-30                 NaT             6
# 111883        2019-12-31                 NaT             6
# 111884        2020-01-02                 NaT             6
# 111885        2020-01-02                 NaT             6
# 111886        2020-01-02                 NaT             6
# 111887        2019-12-30                 NaT             6
# 111888        2019-12-30                 NaT             6
# 111889        2019-12-31                 NaT             6
# 111890        2020-01-02                 NaT             6
# 111891        2020-01-02                 NaT             6
# 111892        2020-01-02                 NaT             6
# 113768        2020-03-20          2020-03-20             6
# 113769        2020-03-20                 NaT             6
# 113770        2020-03-20                 NaT             6
# 113771        2020-03-20                 NaT             6
# 113772        2020-03-20                 NaT             6
# 113773        2020-03-20                 NaT             6
# 113774        2020-03-20          2020-03-20             6
# 113775        2020-03-20                 NaT             6
# 113776        2020-03-20          2020-03-20             6
#
# [33 rows x 23 columns]

# %%
# Products with 5 chemicals in its ingredient
df[df['ChemicalCount'] == 5]
# Out:
#        index  CDPHId                                ProductName    CSFId  CSF  \
# 2555    2555     862                       Best of Skintentions      NaN  NaN
# 2556    2556     862                       Best of Skintentions      NaN  NaN
# 2557    2557     862                       Best of Skintentions      NaN  NaN
# 2558    2558     862                       Best of Skintentions      NaN  NaN
# 2559    2559     862                       Best of Skintentions      NaN  NaN
# ...      ...     ...                                        ...      ...  ...
# 85472  85472   31158  MILANI HYPNOTIC LIGHTS POWDER HIGHLIGHTER  47320.0  NaN
# 85473  85473   31158  MILANI HYPNOTIC LIGHTS POWDER HIGHLIGHTER  47320.0  NaN
# 85474  85474   31158  MILANI HYPNOTIC LIGHTS POWDER HIGHLIGHTER  47320.0  NaN
# 85475  85475   31158  MILANI HYPNOTIC LIGHTS POWDER HIGHLIGHTER  47320.0  NaN
# 85476  85476   31158  MILANI HYPNOTIC LIGHTS POWDER HIGHLIGHTER  47320.0  NaN
#
#        CompanyId       CompanyName BrandName  PrimaryCategoryId  \
# 2555          18   Bliss World LLC     Bliss                 90
# 2556          18   Bliss World LLC     Bliss                 90
# 2557          18   Bliss World LLC     Bliss                 90
# 2558          18   Bliss World LLC     Bliss                 90
# 2559          18   Bliss World LLC     Bliss                 90
# ...          ...               ...       ...                ...
# 85472       1159  MILANI COSMETICS    MILANI                 44
# 85473       1159  MILANI COSMETICS    MILANI                 44
# 85474       1159  MILANI COSMETICS    MILANI                 44
# 85475       1159  MILANI COSMETICS    MILANI                 44
# 85476       1159  MILANI COSMETICS    MILANI                 44
#
#                        PrimaryCategory  ...   CasNumber ChemicalId  \
# 2555               Skin Care Products   ...         NaN        922
# 2556               Skin Care Products   ...         NaN        923
# 2557               Skin Care Products   ...         NaN       1254
# 2558               Skin Care Products   ...     79-81-2       1446
# 2559               Skin Care Products   ...  13463-67-7       1447
# ...                                ...  ...         ...        ...
# 85472  Makeup Products (non-permanent)  ...         NaN      50548
# 85473  Makeup Products (non-permanent)  ...  13463-67-7      50549
# 85474  Makeup Products (non-permanent)  ...  12001-26-2      50550
# 85475  Makeup Products (non-permanent)  ...  13463-67-7      50588
# 85476  Makeup Products (non-permanent)  ...         NaN      50589
#
#                                             ChemicalName InitialDateReported  \
# 2555   Retinol/retinyl esters, when in daily dosages ...          2009-09-14
# 2556                                    Titanium dioxide          2009-09-14
# 2557   2,4-Hexadienal (89% trans, trans isomer; 11% c...          2009-09-14
# 2558   Retinol/retinyl esters, when in daily dosages ...          2009-09-14
# 2559                                    Titanium dioxide          2009-09-14
# ...                                                  ...                 ...
# 85472  Silica, crystalline (airborne particles of res...          2017-07-19
# 85473                                   Titanium dioxide          2017-07-19
# 85474                                               Mica          2017-07-19
# 85475                                   Titanium dioxide          2017-07-19
# 85476  Silica, crystalline (airborne particles of res...          2017-07-19
#
#        MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 2555               2009-09-18              NaT        2009-09-14
# 2556               2009-09-18              NaT        2009-09-14
# 2557               2009-09-18              NaT        2009-09-18
# 2558               2009-09-18              NaT        2009-09-21
# 2559               2009-09-18              NaT        2009-09-21
# ...                       ...              ...               ...
# 85472              2017-08-02              NaT        2017-07-19
# 85473              2017-08-02              NaT        2017-07-19
# 85474              2017-08-02              NaT        2017-07-19
# 85475              2017-08-02              NaT        2017-08-02
# 85476              2017-08-02              NaT        2017-08-02
#
#       ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 2555         2009-09-21          2009-09-21             5
# 2556         2009-09-21          2009-09-21             5
# 2557         2009-09-18          2009-09-18             5
# 2558         2009-09-21                 NaT             5
# 2559         2009-09-21                 NaT             5
# ...                 ...                 ...           ...
# 85472        2017-07-19                 NaT             5
# 85473        2017-07-19                 NaT             5
# 85474        2017-07-19                 NaT             5
# 85475        2017-08-02                 NaT             5
# 85476        2017-08-02                 NaT             5
#
# [105 rows x 23 columns]

# %%
df[(df['ChemicalCount'] > 4)]['CompanyName'].value_counts()
# Out:
# Regis Corporation        96
# Palladio Beauty Group    64
# Bliss World LLC          24
# Puritan's Pride          10
# Vitamin World, Inc.      10
# Cosmopharm Ltd.           9
# MILANI COSMETICS          6
# Good 'N Natural           5
# Name: CompanyName, dtype: int64

# %% [markdown]
# Một số điều rút ra từ việc xem xét thông tin các sản phẩm chứa nhiều chất hóa học trong thành phần:
# - Hãng 'Regis Corporation' có vẻ rất thích sử dụng hóa chất, các sản phẩm chứa nhiều hóa chất nhất trong dataset này đều do hãng này sản xuất...
# - Kế đến chúng ta có hãng 'Palladio Beauty Group', nếu như bảng vàng các sản phẩm chứa từ 7 chất hóa học trở lên bị Regis Corporation độc chiếm thì Palladio Beauty Group cũng chiếm đa số trong các sản phẩm chứa từ 5 tới 6 chất hóa học.
# Nói chung là nếu thích sử dụng các loại mỹ phẩm thiên nhiên, thân thiện với môi trường... thì nên né 2 hãng này ra.

# %% [markdown]
# <h3>Câu 4: Top 5 Các brand có nhiều sản phẩm nhất

# %% [markdown]
# Tìm hiểu top 5 hãng mỹ phẩm có nhiều sản phẩm trên thị trường nhất. Có thể ta sẽ dựa vào đó để tìm kiếm sản phẩm phù hợp

# %%
top5_brand = df["BrandName"].value_counts().to_frame("counts").head()
top5_brand
# Out:
#                    counts
# SEPHORA              3394
# NYX                  3227
# bareMinerals         3158
# Revlon               2335
# Charlotte Tilbury    2297

# %%
top5_brand.plot.barh(ylabel="Số lượng sản phẩm",xlabel="Tên Nhãn Hàng")
# Out:
# <AxesSubplot:xlabel='Tên Nhãn Hàng', ylabel='Số lượng sản phẩm'>

# %% [markdown]
# - Đây là 5 nhãn hàng mĩ phẩm có nhiều sản phẩm nhất
# - Đứng đầu là **SEPHORA** và thứ 5 là **Charlotte Tilbury**
# - Có thể thấy **SEPHORA**, **NYX**, **bareMinerals** là các nhãn hàng có nhiều sản phẩm nhất và chênh lệch số lượng sản phẩm giữa 3 nhãn hàng này là không nhiều.
# - **Sephora** là chuỗi cửa hàng mỹ phẩm của Pháp được thành lập vào năm 1969. Với gần 300 nhãn hiệu, cùng với nhãn hiệu cá nhân sở hữu riêng, *Sephora* cung cấp sản phẩm làm đẹp bao gồm đồ trang điểm, dưỡng da, dưỡng thể, nước hoa, sơn móng và dưỡng tóc.
# - **NYX Professional Makeup** là một công ty mỹ phẩm của Mỹ là công ty con của L'Oréal. Công ty được thành lập tại Los Angeles bởi Toni Ko vào năm 1999. Nó được đặt theo tên của Nyx, nữ thần bóng đêm của Hy Lạp.
# - Thương hiệu mỹ phẩm **bareMinerals** hay còn được biết đến với tên gọi khác là Bare Escentuals được thành lập bởi Leslie Blodgett vào năm 1994, với dòng sản phẩm truyền thống là phấn bột khoáng, là một thương hiệu mỹ phẩm chăm sóc da xuất xứ từ San Francisco, Mỹ.
# - Sau top 3 thì có sự chênh lệch khá đáng kể khoảng 800-1000 sản phẩm ở 2 vị trí tiếp theo là **Revlon** và **Charlotte Tilbury**
# - **Revlon** là một công ty hóa mỹ phẩm Mỹ được thành lập vào năm 1932.
# - **Charlotte Tilbury MBE** được biết đến là chuyên gia trang điểm người Anh nổi tiếng và quen thuộc trong giới ngôi sao Hollywood. Đồng thời, cô cũng kiêm chức Biên tập viên làm đẹp cho tạp chí danh tiếng Vogue Anh và Đại sứ toàn cầu cho các chị em vào ngày Quốc tế Phụ nữ. Năm 2013, Charlotte Tilbury đã ra mắt thương hiệu làm đẹp của riêng mình mang tên **Charlotte Tilbury Beauty Ltd.** tại Selfridges(London).
